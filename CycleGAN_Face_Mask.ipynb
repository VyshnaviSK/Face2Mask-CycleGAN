# %% [markdown]
# <a href="https://colab.research.google.com/github/VyshnaviSK/Face2Mask-CycleGAN/blob/main/CycleGAN_Face_Mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/VyshnaviSK/Face2Mask-CycleGAN
# Out:
# Cloning into 'Face2Mask-CycleGAN'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 70 (delta 16), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (70/70), done.

# %%
import os
os.chdir('Face2Mask-CycleGAN/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 20.8 MB/s
# ...
#      |████████████████████████████████| 68 kB 8.6 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655249 sha256=0ffdbc5dc317f8364fec440f5e7c659fab19fd50a9068c7dc8480e14c2155ccd
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=ffb0af87100d74b5be7912b71a76f74d6e39b6b8ff0fe700366dcd747ad2a8ae
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python train.py --dataroot '/content/drive/My Drive/mask' --name MaskFacee --model cycle_gan --batch_size 4 --checkpoints_dir '/content/drive/My Drive/train_chkpts' --continue_train --epoch_count 183
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/My Drive/train_chkpts	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask  	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 183                           	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py --dataroot '/content/drive/My Drive/mask/TA' --name MaskFacee --model test --no_dropout --checkpoints_dir '/content/drive/My Drive/train_chkpts' --results_dir '/content/drive/My Drive/resA' --num_test 70
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/My Drive/train_chkpts	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask/TA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot '/content/drive/My Drive/mask/blah' --name MaskFacee --model test --no_dropout --checkpoints_dir '/content/drive/My Drive/train_chkpts' --results_dir '/content/drive/My Drive/resB' --preprocess 'None' --num_test 10
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/My Drive/train_chkpts	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask/blah	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...
