# %% [markdown]
# <a href="https://colab.research.google.com/github/VyshnaviSK/Face2Mask-CycleGAN/blob/main/CycleGAN_Face_Mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/VyshnaviSK/Face2Mask-CycleGAN
# Out:
# Cloning into 'Face2Mask-CycleGAN'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 45 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %%
import os
os.chdir('Face2Mask-CycleGAN/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 18.0MB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp37-none-any.whl size=655251 sha256=31073eee7a7f37c7dfda5c14a620cfa1a4e101e76ffe56891336837177a49117
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp37-none-any.whl size=5712 sha256=b0ed4c3ebd5d0d769380b7659fa4b15a763cb8a50dba9bd5647901a27ef1df35
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python train.py --dataroot '/content/drive/My Drive/mask' --name Face_Mask --model cycle_gan --batch_size 4 --checkpoints_dir '/content/drive/My Drive/checkpoints'
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/My Drive/trial_checkpt	[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask  	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %%
# !python test.py --dataroot '/content/drive/My Drive/mask/testA' --name Face2Mask2 --model test --no_dropout --checkpoints_dir '/content/drive/My Drive/mask/checkpoints_new' --results_dir '/content/drive/My Drive/mask/resultAA' --num_test 500
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/My Drive/mask/checkpoints_new	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask/testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot '/content/drive/My Drive/mask/testB' --name Face2Mask2 --model test --no_dropout --checkpoints_dir '/content/drive/My Drive/mask/checkpoint_new' --results_dir '/content/drive/My Drive/mask/resultsmask' --num_test 500
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/My Drive/mask/checkpoint_new	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/mask/testB	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...
